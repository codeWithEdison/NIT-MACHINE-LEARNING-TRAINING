# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Read the CSV file
df = pd.read_csv('music (1).csv')

plt.scatter(df['age'], pd.factorize(df['genre'])[0], c=df['gender'], cmap='viridis')
plt.show()
