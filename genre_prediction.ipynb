# %%
import pandas as pd
music = pd.read_csv('music.csv')
music
# Out:
#     age  gender      genre
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %%
x = music.drop(columns =["genre"])
# x

# %%
y = music['genre']
y
# Out:
# 0        HipHop
# 1        HipHop
# 2        HipHop
# 3          Jazz
# 4          Jazz
# 5          Jazz
# 6     Classical
# 7     Classical
# 8     Classical
# 9         Dance
# 10        Dance
# 11        Dance
# 12     Acoustic
# 13     Acoustic
# 14     Acoustic
# 15    Classical
# 16    Classical
# 17    Classical
# Name: genre, dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model.fit(x,y)
predictions = model.predict(pd.DataFrame([[21, 1], [22, 0]], columns=x.columns))
print(predictions)
# music
# Out:
# ['HipHop' 'Dance']

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score, # Formula accuracy : (TP + TN) / (TP + TN + FP + FN)
    precision_score, # Formula: TP / (TP + FP)
    recall_score, 
    f1_score, 
    mean_absolute_error, 
    mean_squared_error, 
    r2_score,  
)

label_encoder = LabelEncoder()
y_encoder = label_encoder.fit_transform(y)
x_train, x_test ,y_train, y_test = train_test_split(
    x,y_encoder, test_size = 0.2, random_state=42)

model = DecisionTreeClassifier()
model.fit(x_train,y_train )
y_pred = model.predict(x_test)

y_pred_labels = label_encoder.inverse_transform(y_pred)
# print(x_test)
# print(y_pred_labels)

accuracy = model.score(x_test,y_test )
print(f"Accuracy: {accuracy * 100:.3f}%")

precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average ="macro")
f1 = f1_score(y_test, y_pred, average="macro")

print(f"precidion : {precision:.2f}")
print(f"recall : {recall:.2f}")
print(f"f1 score  : {f1:.2f}")
# Out:
# Accuracy: 55.556%
# precidion : 0.50
# recall : 0.50
# f1 score  : 0.47
